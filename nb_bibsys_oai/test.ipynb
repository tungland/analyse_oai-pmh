# %%
import requests
from bs4 import BeautifulSoup

# %%
list_sets = requests.get("https://bibsys.alma.exlibrisgroup.com/view/oai/47BIBSYS_NB/request?verb=ListSets")
list_metadata_formats = requests.get("https://www.nb.no/oai/repository?verb=ListMetadataFormats")

# %%
soup = BeautifulSoup(list_sets.content, "lxml-xml")

# %%
for x in soup.find_all("set"):
    print(x.text)
# Out:
# oai_testposteroai_testposter
# oaioai
# oai_digitaliseringeroai_digitaliseringer
# NBdigital_ikke_periodicaNBdigital ikke periodica
# oai_digital_plikt_for_bibliofil_depotoai_digital_plikt_for_bibliofil_depot
# norboknorbok
# NBdigital_periodicaNBdigital_periodica
# NBdigitalNBdigital
# oai_komplettoai_komplett
# nb_bibliografisknb_bibliografisk
# oai_share_vde_test_efoai_share_vde_test_ef
# ISSNISSN
# oai_depot_holding_testoai_depot_holding_test
# NBdigital_ikke_periodica_testNBdigital_ikke_periodica_test
# oai_depot_testoai_depot_test
# oai_depot_lokale_773oai_depot_lokale_773
# oai_depot_bibnivaaoai_depot_bibnivaa
# NBdigital_pliktNBdigital_plikt
# oai_depot_ianalytteroai_depot_ianalytter
# oai_share_vdeoai_share_vde

# %%
url = "https://bibsys.alma.exlibrisgroup.com/view/oai/47BIBSYS_NB/request?verb=ListRecords&from=2023-01-11T11%3A27%3A57Z&until=2023-01-12T11%3A27%3A57Z&set={set}&metadataPrefix=marc21"

#url = "https://bibsys.alma.exlibrisgroup.com/view/oai/47BIBSYS_NB/request?verb=ListRecords&set={set}&metadataPrefix=marc21"

# %%
res = requests.get(url.format(set="norbok"))
print(res.text)
# Out:
# <?xml version="1.0" encoding="UTF-8"?><OAI-PMH xsi:schemaLocation="http://www.openarchives.org/OAI/2.0/ http://www.openarchives.org/OAI/2.0/OAI-PMH.xsd" xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">
#   <responseDate>2023-12-13T14:22:21Z</responseDate>
#   <request verb="ListRecords" metadataPrefix="marc21" set="norbok" until="2023-01-12T11:27:57Z" from="2023-01-11T11:27:57Z">https://bibsys-g.alma.exlibrisgroup.com/view/oai/47BIBSYS_NB/request</request>
# <ListRecords><record><header><identifier>oai:nb.bibsys.no:990010369714702202</identifier><datestamp>2023-01-12T03:21:41Z</datestamp><setSpec>nb_bibliografisk</setSpec><setSpec>NBdigital_ikke_periodica</setSpec><setSpec>oai_komplett</setSpec><setSpec>norbok</setSpec></header><metadata>
# ...

# %%
# Out:
# <?xml version="1.0" encoding="UTF-8"?><OAI-PMH xsi:schemaLocation="http://www.openarchives.org/OAI/2.0/ http://www.openarchives.org/OAI/2.0/OAI-PMH.xsd" xmlns="http://www.openarchives.org/OAI/2.0/" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance">
#   <responseDate>2023-05-11T14:10:18Z</responseDate>
#   <request verb="ListRecords" metadataPrefix="marc21" set="oai">https://bibsys-g.alma.exlibrisgroup.com/view/oai/47BIBSYS_NB/request</request>
#   <error code="noRecordsMatch">The combination of the values of the from, until, set and metadataPrefix arguments results in an empty list.</error>
# </OAI-PMH>
